# %%
import pandas as pd
import numpy as np
from keras.datasets import imdb
from keras.models import Sequential,load_model
from keras.layers import Dense,Embedding,SimpleRNN
from keras.preprocessing import sequence
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ...

# %%
word_index = imdb.get_word_index()
reverse_words = {value:key for key,value in word_index.items()}

# %%
model = load_model('simple_rnn.h5')
# Out:
# WARNING:tensorflow:From c:\Users\shash\.conda\envs\flaskenv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          12800000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 12833025 (48.95 MB)
# Trainable params: 12833025 (48.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.0178111 , -0.01968911,  0.06259289, ...,  0.02470858,
#          -0.0472133 ,  0.07598201],
#         [ 0.0084881 , -0.00742086,  0.03203985, ..., -0.00072223,
#           0.03657529, -0.00117228],
#         [ 0.03389908, -0.04400339, -0.0246315 , ...,  0.02341128,
#           0.02668096, -0.00469601],
#         ...,
#         [-0.00962769, -0.01108012, -0.04542623, ..., -0.04031939,
#           0.00038819, -0.00166057],
#         [ 0.03370491,  0.00204096,  0.02800294, ...,  0.00158552,
#           0.0489234 ,  0.01561066],
#         [-0.00367943, -0.04923299, -0.00119253, ...,  0.04118655,
#           0.04241556,  0.02464699]], dtype=float32),
#  array([[-0.13485108,  0.09202401,  0.17084475, ..., -0.0014885 ,
#           0.04571094, -0.10138246],
#         [-0.00203042, -0.16650221, -0.13591254, ..., -0.15473822,
#           0.10124222,  0.05620582],
#         [ 0.09222374,  0.1617077 , -0.07218269, ..., -0.05414015,
#           0.13017991, -0.02119765],
# ...

# %%
def decode_review(original):
    return ' '.join([reverse_words.get(i-3,'?') for i in original])

# %%
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word,2)+3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
def movieReview(rev):
    processed_input = preprocess_text(rev)

    prediction = model.predict(processed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'

    return sentiment,prediction[0][0]

# %%
review = "The Movie is fanastic and quite Thrilling"

# %%
setminent,pred=movieReview(review)
# Out:
# 1/1 [==============================] - 0s 368ms/step

# %%
print("The Movie Review Is this:")
print(f"The Setiment of the m ovie is: {setminent}")
print(f"The prediction of positive/negative is: {pred}")
# Out:
# The Movie Review Is this:
# The Setiment of the m ovie is: Negative
# The prediction of positive/negative is: 0.47448965907096863
